# %% [markdown]
# <a href="https://colab.research.google.com/github/Hallymhwangbo/2020-AI_minseo/blob/master/04_4_xor_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np

# %%
x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]
#XOR
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
model = Sequential()
model.add(Dense(2, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='model_xor.png', show_shapes=True)

# %%
model.fit(x_data, y_data, batch_size=1, nb_epoch=1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8087
# Epoch 2/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7894
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7754
# Epoch 4/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7633
# Epoch 5/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7479
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7435
# Epoch 7/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7362
# Epoch 8/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7290
# Epoch 9/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7254
# Epoch 10/1000
# ...

# %%
hypothesis = model.predict_proba(x_data)
print(hypothesis)
# Out:
# [[0.0067096]
#  [0.9882217]
#  [0.9883632]
#  [0.0057006]]

# %%
predicted = hypothesis > 0.5
print(predicted)
# Out:
# [[False]
#  [ True]
#  [ True]
#  [False]]
